# %% [markdown]
# # Final Data Analysis

# %% [markdown]
# # Table of Contents
#
# 1. Import Libraries and Data
# 2. Data Prep
# 3. Data Analysis

# %% [markdown]
# # 1. Import Libraries and Data

# %%
# Import coding libraries.
import pandas as pd
import numpy as np
import os

# Import visualization libraries.
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import scipy

# Confirm execution.
print(f'Import libraries completed')
# Out:
# Import libraries completed

# %%
# Import PKL as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/'
file_name = 'ARWU_Prepared.pkl'
df_arwu = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_arwu
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2                University of Cambridge
# 2             3                    Stanford University
# 3             4     University of California, Berkeley
# 4             5  Massachusetts Institute of Technology
# ...         ...                                    ...
# 4892    401-500                  University of Trieste
# 4893    401-500                 University of Zaragoza
# 4894    401-500                 Wayne State University
# 4895    401-500        Vienna University of Technology
# 4896    401-500                 Wake Forest University
#
#                        country national_rank  total_score  alumni  award  \
# 0     United States of America             1        100.0   100.0  100.0
# 1               United Kingdom             1         73.6    99.8   93.4
# 2     United States of America             2         73.4    41.1   72.2
# ...

# %%
# Import PKL as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/'
file_name = 'CWUR_Prepared.pkl'
df_cwur = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_cwur
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
# Import PKL as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/'
file_name = 'Times_Prepared.pkl'
df_times = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %% [markdown]
# # 2. Data Prep

# %% [markdown]
# ## 1. ARWU

# %%
# DataFrame data types
df_arwu.dtypes
# Out:
# world_rank          object
# university_name     object
# country             object
# national_rank       object
# total_score        float64
# alumni             float64
# award              float64
# hici               float64
# ns                 float64
# pub                float64
# pcp                float64
# year                 int64
# dtype: object

# %%
# Convert multiple columns to numeric
df_arwu[['world_rank', 'national_rank']] = df_arwu[['world_rank', 'national_rank']].apply(pd.to_numeric, errors='coerce')
df_arwu
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0                University of Cambridge
# 2            3.0                    Stanford University
# 3            4.0     University of California, Berkeley
# 4            5.0  Massachusetts Institute of Technology
# ...          ...                                    ...
# 4892         NaN                  University of Trieste
# 4893         NaN                 University of Zaragoza
# 4894         NaN                 Wayne State University
# 4895         NaN        Vienna University of Technology
# 4896         NaN                 Wake Forest University
#
#                        country  national_rank  total_score  alumni  award  \
# 0     United States of America            1.0        100.0   100.0  100.0
# 1               United Kingdom            1.0         73.6    99.8   93.4
# ...

# %%
# DataFrame data types
df_arwu.dtypes
# Out:
# world_rank         float64
# university_name     object
# country             object
# national_rank      float64
# total_score        float64
# alumni             float64
# award              float64
# hici               float64
# ns                 float64
# pub                float64
# pcp                float64
# year                 int64
# dtype: object

# %%
# DataFrame stats
df_arwu.describe()
# Out:
#         world_rank  national_rank  total_score       alumni       award  \
# count  1102.000000    1628.000000  1101.000000  4896.000000  4895.00000
# mean     50.351180      11.796069    36.383470     9.161724     7.69191
# std      28.758399      14.794314    13.557186    14.140636    15.49411
# min       1.000000       1.000000    23.500000     0.000000     0.00000
# 25%      26.000000       2.000000    27.400000     0.000000     0.00000
# 50%      50.500000       4.000000    31.300000     0.000000     0.00000
# 75%      75.000000      17.000000    41.800000    15.600000    13.40000
# max     100.000000      55.000000   100.000000   100.000000   100.00000
#
#               hici           ns          pub          pcp         year
# count  4895.000000  4875.000000  4895.000000  4895.000000  4897.000000
# mean     16.221491    16.078503    38.254648    21.242329  2009.658566
# std      14.382710    12.511529    13.050809     9.254351     3.197576
# ...

# %%
# Identify null counts of all variables
df_arwu.isnull().sum()
# Out:
# world_rank         3795
# university_name       0
# country               0
# national_rank      3269
# total_score        3796
# alumni                1
# award                 2
# hici                  2
# ns                   22
# pub                   2
# pcp                   2
# year                  0
# dtype: int64

# %%
# Overwrite the DataFrame without records that contain null values in the specified variable.
df_arwu.dropna(subset=['world_rank'], inplace=True)
df_arwu
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0                University of Cambridge
# 2            3.0                    Stanford University
# 3            4.0     University of California, Berkeley
# 4            5.0  Massachusetts Institute of Technology
# ...          ...                                    ...
# 4492        96.0                    McMaster University
# 4493        97.0                     University of Bonn
# 4494        98.0                VU University Amsterdam
# 4495        99.0              Michigan State University
# 4496       100.0                   Texas A&M University
#
#                        country  national_rank  total_score  alumni  award  \
# 0     United States of America            1.0        100.0   100.0  100.0
# 1               United Kingdom            1.0         73.6    99.8   93.4
# ...

# %%
# Overwrite the DataFrame without records that contain null values in the specified variable.
df_arwu.dropna(subset=['total_score'], inplace=True)
df_arwu
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0                University of Cambridge
# 2            3.0                    Stanford University
# 3            4.0     University of California, Berkeley
# 4            5.0  Massachusetts Institute of Technology
# ...          ...                                    ...
# 4492        96.0                    McMaster University
# 4493        97.0                     University of Bonn
# 4494        98.0                VU University Amsterdam
# 4495        99.0              Michigan State University
# 4496       100.0                   Texas A&M University
#
#                        country  national_rank  total_score  alumni  award  \
# 0     United States of America            1.0        100.0   100.0  100.0
# 1               United Kingdom            1.0         73.6    99.8   93.4
# ...

# %%
# DataFrame stats
df_arwu.describe()
# Out:
#         world_rank  national_rank  total_score       alumni        award  \
# count  1101.000000    1101.000000  1101.000000  1101.000000  1101.000000
# mean     50.306994      15.710263    36.383470    25.576658    26.719255
# std      28.734019      16.461983    13.557186    18.650148    22.021721
# min       1.000000       1.000000    23.500000     0.000000     0.000000
# 25%      26.000000       2.000000    27.400000    14.400000    14.100000
# 50%      50.000000       7.000000    31.300000    21.300000    22.200000
# 75%      75.000000      29.000000    41.800000    32.900000    34.000000
# max     100.000000      55.000000   100.000000   100.000000   100.000000
#
#               hici           ns          pub          pcp         year
# count  1101.000000  1101.000000  1101.000000  1101.000000  1101.000000
# mean     35.376748    32.587103    53.767666    31.522343  2009.989101
# std      16.105656    15.019464    12.279979    12.621984     3.163409
# ...

# %%
# Preview the histogram.
df_arwu['total_score'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Preview the histogram.
df_arwu['world_rank'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sub_corr_arwu = df_arwu[['world_rank', 'national_rank', 'total_score', 'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year']]
sub_corr_arwu
# Out:
#       world_rank  national_rank  total_score  alumni  award   hici     ns  \
# 0            1.0            1.0        100.0   100.0  100.0  100.0  100.0
# 1            2.0            1.0         73.6    99.8   93.4   53.3   56.6
# 2            3.0            2.0         73.4    41.1   72.2   88.5   70.9
# 3            4.0            3.0         72.8    71.8   76.0   69.4   73.9
# 4            5.0            4.0         70.1    74.0   80.6   66.7   65.8
# ...          ...            ...          ...     ...    ...    ...    ...
# 4492        96.0            4.0         24.4    12.6   18.8   23.2   15.1
# 4493        97.0            4.0         24.3    15.4   19.8   17.4   21.1
# 4494        98.0            4.0         24.2     0.0    0.0   27.8   18.0
# 4495        99.0           50.0         24.0     8.9    0.0   30.7   21.8
# 4496       100.0           51.0         23.9     0.0    0.0   34.3   22.7
#
#         pub   pcp  year
# 0     100.0  72.4  2005
# 1      70.9  66.9  2005
# ...

# %%
# Review the correlation matrix
sub_corr_arwu.corr()
# Out:
#                world_rank  national_rank  total_score    alumni     award  \
# world_rank       1.000000       0.254474    -0.852613 -0.572141 -0.670591
# national_rank    0.254474       1.000000    -0.286252 -0.416683 -0.366322
# total_score     -0.852613      -0.286252     1.000000  0.769191  0.831950
# alumni          -0.572141      -0.416683     0.769191  1.000000  0.745999
# award           -0.670591      -0.366322     0.831950  0.745999  1.000000
# hici            -0.791032       0.029944     0.870980  0.480494  0.550183
# ns              -0.819060      -0.172964     0.929130  0.584310  0.671199
# pub             -0.606051      -0.217212     0.627578  0.359647  0.197078
# pcp             -0.577886      -0.340867     0.755265  0.639318  0.718257
# year            -0.007224      -0.030349    -0.009685 -0.090787  0.045439
#
#                    hici        ns       pub       pcp      year
# world_rank    -0.791032 -0.819060 -0.606051 -0.577886 -0.007224
# ...

# %%
# Create a subplot with matplotlib
fig, ax = plt.subplots(figsize=(10,10))

# Preview the correlation
sns.heatmap(
	sub_corr_arwu.corr(),
  annot = True,
  ax = ax
  ) 

# Add title
ax.set_title('ARWU Correlation Heatmap', fontsize=16)
# Out:
# Text(0.5, 1.0, 'ARWU Correlation Heatmap')

# %%
# Create the correlation heatmap
corr_arwu = fig
corr_arwu

# %% [markdown]
# ## 2. CWUR

# %%
# DataFrame data types
df_cwur.dtypes
# Out:
# world_rank                int64
# institution              object
# country                  object
# national_rank             int64
# quality_of_education      int64
# alumni_employment         int64
# quality_of_faculty        int64
# publications              int64
# influence                 int64
# citations                 int64
# broad_impact            float64
# patents                   int64
# score                   float64
# year                      int64
# dtype: object

# %%
# DataFrame stats
df_cwur.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
# Identify null counts of all variables
df_cwur.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
# Convert column to numeric
df_cwur[['broad_impact']] = df_cwur[['broad_impact']].apply(pd.to_numeric, errors='coerce')
df_cwur
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
# DataFrame stats
df_cwur.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
# Preview the histogram.
df_cwur['score'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Preview the histogram.
df_cwur['world_rank'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sub_corr_cwur = df_cwur[['world_rank', 'national_rank', 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'score', 'year']]
sub_corr_cwur
# Out:
#       world_rank  national_rank  quality_of_education  alumni_employment  \
# 0              1              1                     7                  9
# 1              2              2                     9                 17
# 2              3              3                    17                 11
# 3              4              1                    10                 24
# 4              5              4                     2                 29
# ...          ...            ...                   ...                ...
# 2195         996              7                   367                567
# 2196         997              4                   236                566
# 2197         998             18                   367                549
# 2198         999             40                   367                567
# 2199        1000             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# ...

# %%
# Review the correlation matrix
sub_corr_cwur.corr()
# Out:
#                       world_rank  national_rank  quality_of_education  \
# world_rank              1.000000       0.238553              0.676166
# national_rank           0.238553       1.000000              0.211975
# quality_of_education    0.676166       0.211975              1.000000
# alumni_employment       0.668529       0.135342              0.606421
# quality_of_faculty      0.663864       0.222833              0.786181
# publications            0.923037       0.326857              0.624657
# influence               0.895871       0.161086              0.645641
# citations               0.856573       0.186797              0.630455
# broad_impact            0.942998       0.173043              0.521615
# patents                 0.698214       0.159440              0.528120
# score                  -0.549098      -0.199756             -0.600541
# year                    0.320844       0.102951              0.427732
#
# ...

# %%
# Create a subplot with matplotlib
fig, ax = plt.subplots(figsize=(10,10))

# Preview the correlation
sns.heatmap(
	sub_corr_cwur.corr(),
  annot = True,
  ax = ax
  ) 

# Add title
ax.set_title('CWUR Correlation Heatmap', fontsize=16)
# Out:
# Text(0.5, 1.0, 'CWUR Correlation Heatmap')

# %%
# Create the correlation heatmap
corr_cwur = fig
corr_cwur

# %% [markdown]
# ## 3. Times

# %%
# DataFrame data types
df_times.dtypes
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international              object
# research                  float64
# citations                 float64
# income                     object
# total_score                object
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# dtype: object

# %%
# Convert multiple columns to numeric
df_times[['world_rank', 'international', 'income', 'total_score']] = df_times[['world_rank', 'international', 'income', 'total_score']].apply(pd.to_numeric, errors='coerce')
df_times
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0     California Institute of Technology
# 2            3.0  Massachusetts Institute of Technology
# 3            4.0                    Stanford University
# 4            5.0                   Princeton University
# ...          ...                                    ...
# 2598         NaN                    Yeungnam University
# 2599         NaN            Yıldız Technical University
# 2600         NaN               Yokohama City University
# 2601         NaN           Yokohama National University
# 2602         NaN                     Yuan Ze University
#
#                        country  teaching  international  research  citations  \
# 0     United States of America      99.7           72.4      98.7       98.8
# 1     United States of America      97.7           54.6      98.0       99.9
# ...

# %%
# DataFrame data types
df_times.dtypes
# Out:
# world_rank                float64
# university_name            object
# country                    object
# teaching                  float64
# international             float64
# research                  float64
# citations                 float64
# income                    float64
# total_score               float64
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# dtype: object

# %%
# DataFrame stats
df_times.describe()
# Out:
#         world_rank     teaching  international     research    citations  \
# count  1112.000000  2603.000000    2594.000000  2603.000000  2603.000000
# mean     98.201439    37.801498      52.007440    35.910257    60.921629
# std      58.097290    17.604218      22.103825    21.254805    23.073219
# min       1.000000     9.900000       7.100000     2.900000     1.200000
# 25%      48.000000    24.700000      33.425000    19.600000    45.500000
# 50%      97.000000    33.900000      50.300000    30.500000    62.500000
# 75%     148.000000    46.400000      69.000000    47.250000    79.050000
# max     200.000000    99.700000     100.000000    99.400000   100.000000
#
#             income  total_score  student_staff_ratio         year
# count  2385.000000  1201.000000          2544.000000  2603.000000
# mean     48.979874    59.846128            18.445283  2014.075682
# std      21.179938    12.803446            11.458698     1.685733
# ...

# %%
# Identify null counts of all variables
df_times.isnull().sum()
# Out:
# world_rank                1491
# university_name              0
# country                      0
# teaching                     0
# international                9
# research                     0
# citations                    0
# income                     218
# total_score               1402
# num_students                59
# student_staff_ratio         59
# international_students      67
# female_male_ratio          233
# year                         0
# dtype: int64

# %%
# Overwrite the DataFrame without records that contain null values in the specified variable.
df_times.dropna(subset=['world_rank'], inplace=True)
df_times
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0     California Institute of Technology
# 2            3.0  Massachusetts Institute of Technology
# 3            4.0                    Stanford University
# 4            5.0                   Princeton University
# ...          ...                                    ...
# 1994       192.0                         Ulm University
# 1997       195.0   Charité - Universitätsmedizin Berlin
# 2000       198.0                   University of Trento
# 2001       199.0     Paris Diderot University – Paris 7
# 2002       200.0             Queen’s University Belfast
#
#                        country  teaching  international  research  citations  \
# 0     United States of America      99.7           72.4      98.7       98.8
# 1     United States of America      97.7           54.6      98.0       99.9
# ...

# %%
# Overwrite the DataFrame without records that contain null values in the specified variable.
df_times.dropna(subset=['total_score'], inplace=True)
df_times
# Out:
#       world_rank                        university_name  \
# 0            1.0                     Harvard University
# 1            2.0     California Institute of Technology
# 2            3.0  Massachusetts Institute of Technology
# 3            4.0                    Stanford University
# 4            5.0                   Princeton University
# ...          ...                                    ...
# 1994       192.0                         Ulm University
# 1997       195.0   Charité - Universitätsmedizin Berlin
# 2000       198.0                   University of Trento
# 2001       199.0     Paris Diderot University – Paris 7
# 2002       200.0             Queen’s University Belfast
#
#                        country  teaching  international  research  citations  \
# 0     United States of America      99.7           72.4      98.7       98.8
# 1     United States of America      97.7           54.6      98.0       99.9
# ...

# %%
# Identify null counts of all variables
df_times.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               9
# research                    0
# citations                   0
# income                    136
# total_score                 0
# num_students               18
# student_staff_ratio        18
# international_students     19
# female_male_ratio         116
# year                        0
# dtype: int64

# %%
# DataFrame stats
df_times.describe()
# Out:
#         world_rank     teaching  international     research    citations  \
# count  1112.000000  1112.000000    1103.000000  1112.000000  1112.000000
# mean     98.201439    51.366097      58.914869    52.874371    76.696853
# std      58.097290    17.162686      21.236682    19.925043    15.642485
# min       1.000000    15.900000      14.800000    13.100000    18.800000
# 25%      48.000000    38.575000      40.700000    37.375000    66.000000
# 50%      97.000000    47.900000      58.700000    48.950000    78.300000
# 75%     148.000000    61.725000      77.000000    65.900000    89.425000
# max     200.000000    99.700000     100.000000    99.400000   100.000000
#
#            income  total_score  student_staff_ratio         year
# count  976.000000  1112.000000          1094.000000  1112.000000
# mean    53.924693    60.111691            15.758501  2013.301259
# std     22.624946    13.158928             9.064041     1.616209
# ...

# %%
# Preview the histogram.
df_times['total_score'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Preview the histogram.
df_times['world_rank'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sub_corr_times = df_times[['world_rank', 'teaching', 'international', 'research', 'citations', 'income', 'total_score', 'student_staff_ratio', 'year']]
sub_corr_times
# Out:
#       world_rank  teaching  international  research  citations  income  \
# 0            1.0      99.7           72.4      98.7       98.8    34.5
# 1            2.0      97.7           54.6      98.0       99.9    83.7
# 2            3.0      97.8           82.3      91.4       99.9    87.5
# 3            4.0      98.3           29.5      98.1       99.2    64.3
# 4            5.0      90.9           70.3      95.4       99.9     NaN
# ...          ...       ...            ...       ...        ...     ...
# 1994       192.0      35.2           58.2      23.9       86.4    58.4
# 1997       195.0      37.3           61.1      22.2       83.8    68.4
# 2000       198.0      30.8           55.9      27.4       87.7    47.1
# 2001       199.0      30.5           64.9      22.9       91.0    29.0
# 2002       200.0      34.1           93.4      33.3       68.9    35.7
#
#       total_score  student_staff_ratio  year
# 0            96.1                  8.9  2011
# ...

# %%
# Review the correlation matrix
sub_corr_times.corr()
# Out:
#                      world_rank  teaching  international  research  citations  \
# world_rank             1.000000 -0.809650      -0.113274 -0.832917  -0.549495
# teaching              -0.809650  1.000000      -0.052895  0.896200   0.260443
# international         -0.113274 -0.052895       1.000000  0.047808   0.067561
# research              -0.832917  0.896200       0.047808  1.000000   0.229320
# citations             -0.549495  0.260443       0.067561  0.229320   1.000000
# income                -0.225471  0.263582      -0.042797  0.305125  -0.140049
# total_score           -0.919340  0.900393       0.137016  0.909208   0.570083
# student_staff_ratio    0.258907 -0.309236       0.154103 -0.189599  -0.232414
# year                  -0.058574 -0.048789       0.158526  0.005212   0.225064
#
#                        income  total_score  student_staff_ratio      year
# world_rank          -0.225471    -0.919340             0.258907 -0.058574
# ...

# %%
# Create a subplot with matplotlib
fig, ax = plt.subplots(figsize=(10,10))

# Preview the correlation
sns.heatmap(
	sub_corr_times.corr(),
  annot = True,
  ax = ax
  ) 

# Add title
ax.set_title('Times Correlation Heatmap', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Times Correlation Heatmap')

# %%
# Create the correlation heatmap
corr_times = fig
corr_times

# %%
# Export plot as an image
file_name = 'correlation_times.png'
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)
corr_times.figure.savefig(file_path, bbox_inches='tight', dpi=300)
print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/04 Analysis/Visualizations/correlation_times.png

# %%
# Export plot as an image
file_name = 'correlation_arwu.png'
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)
corr_arwu.figure.savefig(file_path, bbox_inches='tight', dpi=300)
print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/04 Analysis/Visualizations/correlation_arwu.png

# %%
# Export plot as an image
file_name = 'correlation_cwur.png'
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)
corr_cwur.figure.savefig(file_path, bbox_inches='tight', dpi=300)
print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/04 Analysis/Visualizations/correlation_cwur.png

# %% [markdown]
# ## 4. Regression Dataframe

# %%
# Rename variable
df_cwur.rename(columns = {
	'institution': 'university',
    'score': 'total_score'}, inplace = True)
df_cwur
# Out:
#       world_rank                             university         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
# Add a new column to represent the institution
df_arwu['institution'] = 'ARWU'
df_cwur['institution'] = 'CWUR'
df_times['institution'] = 'Times'

# %%
df_arwu['institution'].value_counts(dropna = False)
# Out:
# institution
# ARWU    1101
# Name: count, dtype: int64

# %%
df_cwur['institution'].value_counts(dropna = False)
# Out:
# institution
# CWUR    2200
# Name: count, dtype: int64

# %%
df_times['institution'].value_counts(dropna = False)
# Out:
# institution
# Times    1112
# Name: count, dtype: int64

# %%
# Keep relevant variables
df_reg_arwu = df_arwu[['total_score', 'institution']].copy()
df_reg_cwur = df_cwur[['total_score', 'institution']].copy()
df_reg_times = df_times[['total_score', 'institution']].copy()
df_reg_arwu
# Out:
#       total_score institution
# 0           100.0        ARWU
# 1            73.6        ARWU
# 2            73.4        ARWU
# 3            72.8        ARWU
# 4            70.1        ARWU
# ...           ...         ...
# 4492         24.4        ARWU
# 4493         24.3        ARWU
# 4494         24.2        ARWU
# 4495         24.0        ARWU
# 4496         23.9        ARWU
#
# [1101 rows x 2 columns]

# %%
df_reg_cwur
# Out:
#       total_score institution
# 0          100.00        CWUR
# 1           91.67        CWUR
# 2           89.50        CWUR
# 3           86.17        CWUR
# 4           85.21        CWUR
# ...           ...         ...
# 2195        44.03        CWUR
# 2196        44.03        CWUR
# 2197        44.03        CWUR
# 2198        44.02        CWUR
# 2199        44.02        CWUR
#
# [2200 rows x 2 columns]

# %%
df_reg_times
# Out:
#       total_score institution
# 0            96.1       Times
# 1            96.0       Times
# 2            95.6       Times
# 3            94.3       Times
# 4            94.2       Times
# ...           ...         ...
# 1994         49.5       Times
# 1997         49.3       Times
# 2000         49.1       Times
# 2001         48.9       Times
# 2002         48.8       Times
#
# [1112 rows x 2 columns]

# %%
# Merge
df_reg_combined = pd.concat([df_reg_arwu, df_reg_cwur, df_reg_times], ignore_index=True)
df_reg_combined
# Out:
#       total_score institution
# 0           100.0        ARWU
# 1            73.6        ARWU
# 2            73.4        ARWU
# 3            72.8        ARWU
# 4            70.1        ARWU
# ...           ...         ...
# 4408         49.5       Times
# 4409         49.3       Times
# 4410         49.1       Times
# 4411         48.9       Times
# 4412         48.8       Times
#
# [4413 rows x 2 columns]

# %%
df_reg_combined['institution'].value_counts(dropna = False)
# Out:
# institution
# CWUR     2200
# Times    1112
# ARWU     1101
# Name: count, dtype: int64

# %%
# Dummy variables
df_reg_combined = pd.get_dummies(df_reg_combined, columns=['institution'], drop_first=True)
df_reg_combined
# Out:
#       total_score  institution_CWUR  institution_Times
# 0           100.0             False              False
# 1            73.6             False              False
# 2            73.4             False              False
# 3            72.8             False              False
# 4            70.1             False              False
# ...           ...               ...                ...
# 4408         49.5             False               True
# 4409         49.3             False               True
# 4410         49.1             False               True
# 4411         48.9             False               True
# 4412         48.8             False               True
#
# [4413 rows x 3 columns]

# %% [markdown]
# ARWU is the baseline for the regression analysis.

# %%
# Convert T/F
dummy_columns = ['institution_CWUR', 'institution_Times']
df_reg_combined[dummy_columns] = df_reg_combined[dummy_columns].astype(int)
df_reg_combined
# Out:
#       total_score  institution_CWUR  institution_Times
# 0           100.0                 0                  0
# 1            73.6                 0                  0
# 2            73.4                 0                  0
# 3            72.8                 0                  0
# 4            70.1                 0                  0
# ...           ...               ...                ...
# 4408         49.5                 0                  1
# 4409         49.3                 0                  1
# 4410         49.1                 0                  1
# 4411         48.9                 0                  1
# 4412         48.8                 0                  1
#
# [4413 rows x 3 columns]

# %% [markdown]
# # 3. Regression Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# Set regression model
X = df_reg_combined[['institution_CWUR', 'institution_Times']]
y = df_reg_combined['total_score']
X = sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = sm.OLS(y_train, X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_score   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     943.3
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):          2.05e-320
# Time:                        16:20:52   Log-Likelihood:                -11736.
# No. Observations:                3089   AIC:                         2.348e+04
# Df Residuals:                    3086   BIC:                         2.350e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                36.2090      0.391     92.622      0.000      35.443      36.976
# ...

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Create scatterplot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, color='red')
plt.xlabel('Actual Total Score')
plt.ylabel('Predicted Total Score')
plt.title('Actual vs Predicted Total Score')
plt.savefig('actual_vs_predicted_total_score.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/3j/v2m3l9zn34b54kd8m0lcnww40000gn/T/ipykernel_17336/744531389.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, color='red')

# %%
plt.savefig('actual_vs_predicted_total_score.png', dpi=300, bbox_inches='tight')

# %%
# Create scatterplot
plt.figure(figsize=(8, 6))
plt.scatter(y_test[df_reg_combined['institution_CWUR'] == 1], 
            y_pred[df_reg_combined['institution_CWUR'] == 1], 
            color='blue', alpha=0.5, label='CWUR')
plt.scatter(y_test[df_reg_combined['institution_Times'] == 1], 
            y_pred[df_reg_combined['institution_Times'] == 1], 
            color='green', alpha=0.5, label='Times')
plt.scatter(y_test[(df_reg_combined['institution_CWUR'] == 0) & 
                   (df_reg_combined['institution_Times'] == 0)], 
            y_pred[(df_reg_combined['institution_CWUR'] == 0) & 
                   (df_reg_combined['institution_Times'] == 0)], 
            color='orange', alpha=0.5, label='ARWU')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, color='red')
plt.xlabel('Actual Total Score')
plt.ylabel('Predicted Total Score')
plt.title('Actual vs Predicted Total Score')
plt.legend(title='Institution')
plt.savefig('actual_vs_predicted_total_score_by_institution.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/3j/v2m3l9zn34b54kd8m0lcnww40000gn/T/ipykernel_17336/443599641.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, color='red')

# %% [markdown]
# # 4. Distribution Analysis

# %%
# Import PKL as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/'
file_name = 'combined_rankings_12_15.pkl'
df_combined = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_combined
# Out:
#      ranking_institution  year  world_rank  \
# 0                   CWUR  2012           1
# 1                   CWUR  2012           2
# 2                   CWUR  2012           3
# 3                   CWUR  2012           4
# 4                   CWUR  2012           5
# ...                  ...   ...         ...
# 1196                ARWU  2015          96
# 1197                ARWU  2015          97
# 1198                ARWU  2015          98
# 1199                ARWU  2015          99
# 1200                ARWU  2015         100
#
#                                  university            country/region   score
# 0                        Harvard University  United States of America  100.00
# 1     Massachusetts Institute of Technology  United States of America   91.67
# 2                       Stanford University  United States of America   89.50
# 3                   University of Cambridge            United Kingdom   86.17
# ...

# %%
# Identify countries
df_combined['country/region'].value_counts(dropna = False)
# Out:
# country/region
# United States of America    619
# United Kingdom              108
# Japan                        48
# Canada                       47
# Australia                    46
# Switzerland                  45
# France                       45
# Netherlands                  44
# Germany                      42
# Sweden                       26
# Israel                       22
# South Korea                  16
# Belgium                      15
# China                        12
# Denmark                      12
# Norway                       11
# Singapore                    10
# Hong Kong                     8
# Finland                       8
# Italy                         4
# Portugal                      4
# Russia                        3
# Taiwan                        2
# India                         2
# Turkey                        1
# Name: count, dtype: int64

# %%
# Assign regions based on the country
def assign_region(country):
    if country in ['China', 'Hong Kong', 'Taiwan', 'Singapore', 'South Korea', 'Japan']:
        return 'China-Aligned Region'
    elif country in ['United States of America', 'United Kingdom', 'Canada', 'Australia', 'Netherlands', 'Germany', 'France', 'Sweden', 'Switzerland', 'Belgium', 'Denmark', 'Norway', 'Finland', 'Israel']:
        return 'Western-Aligned Region'
    else:
        return 'Non-Aligned'
df_combined['alignment'] = df_combined['country/region'].apply(assign_region)
df_combined
# Out:
#      ranking_institution  year  world_rank  \
# 0                   CWUR  2012           1
# 1                   CWUR  2012           2
# 2                   CWUR  2012           3
# 3                   CWUR  2012           4
# 4                   CWUR  2012           5
# ...                  ...   ...         ...
# 1196                ARWU  2015          96
# 1197                ARWU  2015          97
# 1198                ARWU  2015          98
# 1199                ARWU  2015          99
# 1200                ARWU  2015         100
#
#                                  university            country/region   score  \
# 0                        Harvard University  United States of America  100.00
# 1     Massachusetts Institute of Technology  United States of America   91.67
# 2                       Stanford University  United States of America   89.50
# 3                   University of Cambridge            United Kingdom   86.17
# ...

# %%
# Export DataFrame to a .xlsx file
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/'
file_name = 'distribution_set.xlsx'
file_path = os.path.join(folder_path, '02 Data', 'Prepared Data', file_name)
os.makedirs(os.path.dirname(file_path), exist_ok=True)
df_combined.to_excel(file_path)
print(f'DataFrame exported to {file_path}.')
# Out:
# DataFrame exported to /Users/bertpearce/Documents/Python Projects/2024.08.01 University Ranking Analysis/02 Data/Prepared Data/distribution_set.xlsx.

# %%
# Identify countries
df_combined['alignment'].value_counts(dropna = False)
# Out:
# alignment
# Western-Aligned Region    1090
# China-Aligned Region        96
# Non-Aligned                 14
# Name: count, dtype: int64

# %%
df_combined[df_combined['ranking_institution'] == 'CWUR']['alignment'].value_counts()
# Out:
# alignment
# Western-Aligned Region    354
# China-Aligned Region       40
# Non-Aligned                 6
# Name: count, dtype: int64
